# %% [markdown]
# <a href="https://www.kaggle.com/code/lumarian/web-scraping-indeed-job-postings?scriptVersionId=159975507" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Web Scraping Indeed Job Postings
# This is my first web scraping project and it's still in progress. I'm gathering data from Indeed job postings and then analyzing them to find any trends or patterns.

# %%
import bs4
from bs4 import BeautifulSoup
import requests
import time
import random as ran
import sys
import pandas as pd
import re

# %% [markdown]
# ## Getting Started
# Preparing all the packages and getting an API key from a web scraper.

# %%
url = "https://api.scrapingdog.com/indeed"
api_key = "65ae0b013dc7fb6d1a5d3145"
jobs_url = "https://www.indeed.com/"

params = {"api-key": api_key, "url": jobs_url}
print(params)
# Out:
# {'api-key': '65ae0b013dc7fb6d1a5d3145', 'url': 'https://www.indeed.com/'}

# %%
target_url = "https://www.indeed.com/"
scrape_url = "https://api.scrapingdog.com/scrape?api_key=65ae0b013dc7fb6d1a5d3145&url=https://www.indeed.com/jobs?q=&l=Los+Angeles%2C+CA&from=searchOnHP&vjk=89eb443ee8b65264&dynamic=false"
api_key = "65ae0b013dc7fb6d1a5d3145"
payload = {'api-key': api_key, 'url':scrape_url}
head= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.94 Safari/537.36",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    "Connection": "keep-alive",
    "Accept-Language": "en-US,en;q=0.9,lt;q=0.8,et;q=0.7,de;q=0.6",
}

resp = requests.get(scrape_url)

print("status is", resp.status_code)
# Out:
# status is 200

# %% [markdown]
# ## Extracting Items from HTML
# I'm making lists of the features that I want to analyze later. Some of them, like location and salary, need to be re-formatted and cleaned before it goes into the dataframe.

# %%
soup = BeautifulSoup(resp.text, "html.parser")
allData = soup.findAll('div', attrs={'data-testid': 'slider_container'})

# %%
def get_title(x):
    new_x = x.find('span', id=re.compile("jobTitle"))
    return new_x.text    

def get_pay(x):
    new_x = x.find('div', attrs={'data-testid': 'attribute_snippet_testid'})
    if new_x is None:
        return "Not Found"
    elif '$' in str(new_x):        
        return new_x.text
    
def get_loc(x):
    new_x = x.find('div', attrs={'data-testid': 'text-location'})
    if new_x is None:
        new_x="Not Found"
    else:
        return new_x.text
    
def get_comp(x):
    new_x = x.find('span', attrs={'data-testid': 'company-name'})
    if new_x is None:
        new_x="Not Found"
    else:
        return new_x.text
    
pays = list(map(get_pay, allData))
locs = list(map(get_loc, allData))
comps = list(map(get_comp, allData))
titles = list(map(get_title, allData))

# checking lengths of the lists
print(len(titles), len(locs), len(pays), len(comps))
# Out:
# 15 15 15 15

# %% [markdown]
# ## Creating Dataframe
# Now that I have stored the relevant data in lists, I can now combine them into a pandas dataframe.

# %%
jobData = pd.DataFrame({'Job Title':titles, 'Location': locs, 'Salary':pays, 'Company':comps})
jobData
# Out:
#                                             Job Title  \
# 0                                           Estimator
# 1              Substitute Teacher - Highest Pay in LA
# 2   Boba Time HP/USC Team Member ($18.25/$19.5 to ...
# 3              School Bus Driver. *Training Provided*
# 4                                          Dog Walker
# 5                                              Roofer
# 6                                    Front Desk Agent
# 7              Full Charge Bookkeeper (Music Touring)
# 8                                988 Crisis Counselor
# 9                                   AI Content Writer
# 10                                  Appointment Clerk
# 11                     Apparel Production Coordinator
# 12                                      Payroll Clerk
# 13                               Litigation Secretary
# 14                                Urban Forestry Lead
#
#                                          Location                     Salary  \
# 0   Los Angeles, CA 90022 (East Los Angeles area)  $72,000 - $110,000 a year
# 1                                 Los Angeles, CA          $25 - $41 an hour
# 2    Los Angeles, CA 90007 (Exposition Park area)    $18.25 - $30.00 an hour
# 3                           Los Angeles, CA 90012          $26 - $33 an hour
# 4                                Santa Monica, CA          $16 - $50 an hour
# 5                        Valley Village, CA 91607    $25.56 - $27.89 an hour
# 6          Los Angeles, CA 90027 (Los Feliz area)          $21 - $23 an hour
# 7                            El Segundo, CA 90245   $80,000 - $99,000 a year
# 8                           Los Angeles, CA 90067                $24 an hour
# 9                       Remote in Los Angeles, CA          $20 - $25 an hour
# 10                                    Anaheim, CA    $25.30 - $28.03 an hour
# 11   Los Angeles, CA 90058 (Central Alameda area)  $50,000 - $700,000 a year
# 12          Los Angeles, CA 90034 (Mid City area)          $20 - $24 an hour
# 13             Glendale, CA 91203 (Glendale area)          $30 - $35 an hour
# 14        Los Angeles, CA 90015 (Pico Union area)          $20 - $21 an hour
#
#                                Company
# 0              Duran's Body Shop, Inc.
# 1                  Teachers On Reserve
# 2                    It's Boba Time HP
# 3                          Zum SF Inc.
# 4                     Spot Dog Walking
# 5                       PAC Properties
# 6                           Cara Hotel
# 7         Woodwest Business Management
# 8   Didi Hirsch Mental Health Services
# 9                       DataAnnotation
# 10                   Kaiser Permanente
# 11                  Honey Apparel Inc.
# 12                       Brody Pennell
# 13             LAWYERS for JUSTICE, PC
# 14  Koreatown Youth & Community Center

# %% [markdown]
# ## Project Loading...
# This is where I'm at for now on this project. My plan for the next steps are:
# * Edit the Salary variable to make it numeric and also standardize the units to per hour, since some of them are per month or per year.
# * Categorize the job types using NLP to find trends with the salaries
#
# Some other thoughts:
# * It would be nice if I could obtain company size in numbers of employees to see if that has an impact on the pay.
# * It would be interesting if I could import the data into a mapping software like ArcGIS and plot them there to observe any location-based patterns.

# %%
print(allData)
# Out:
# [<div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@media (max-width: 400px){.css-dekpa h2{-webkit-line-clamp:4;}}</style><div class="css-dekpa e37uo190"><style data-emotion="css 1u6tfqq">.css-1u6tfqq{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;-webkit-box-orient:vertical;font-size:1.125rem;line-height:1.5rem;margin:0;color:#2d2d2d;letter-spacing:-0.06px;overflow:hidden;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;font-weight:600;-webkit-line-clamp:2;}</style><h2 class="jobTitle css-1u6tfqq eu4oa1w0" tabindex="-1"><a aria-label="full details of Estimator" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-ci="424979820" data-empn="8390929308540166" data-hide-spinner="true" data-hiring-event="false" data-jk="7a9d5b091891c89f" data-mobtk="1hkoetq47jgaq800" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0BOgW4x5Ae8Am2CByjLCoecbzEpL2aKfBlJa0seDH69MSip7gsMuZVtC4ei7C7kqlax5nW5KIAAeOOJagOAWQv7Ftvgyl8mjJwRmAhamQR30eN88WMhV00AyVAOGBzFOhg11D7N1ir0iw_s_ttxJHblbkX7EzMNmBLoRVUvixndncnXayWQx-y5f2WU5W3VpeBerJa3nAtnC7GFs3ZlUosMqrPYCB9OxwYFZObpQmtmO1QENiZwEhdKmbcNWLEKLe-FcW1vgqaMDFDhees0xGmyD_qXJk6-SZ2j5ED2vt8j5CjFGa_XzYULycDP9KoO9HtJYEyV0euf_kwO-3fZuBu1w03TyN7RjK0R5GaxNb6t2Da6JnRmyYeO3M8B4YrKy_h11Brguhzfe1nc2h_b5Xub5K8sES8meV-gyBeVT30e9p3RenO99VT2AKGU-2_-wE6YjIrFQZsqfCuPw9ZviEuq6jpEbvUDJAs4t80lu29iyQrCX8kIhl59B2hgdYJkvIAP1y7GnFenKiHKeaJHOwsQA8K6xiJHUUnhmY7u31Dzgq3aGb71h1Fmy_aLWg1eIEQEyE75FbXGN-MOg_FB7hIBm7xTWe30jx0=&amp;xkcb=SoAD6_M3FYV4iVQ9SB0LbzkdCdPP&amp;p=0&amp;fvj=1&amp;vjs=3" id="sj_7a9d5b091891c89f" role="button"><span id="jobTitle-7a9d5b091891c89f" title="Estimator">Estimator</span></a></h2><div class="css-njufu0 e37uo190"><div class="css-kyg8or eu4oa1w0"><style data-emotion="css 1vjbk9u">.css-1vjbk9u{-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:1px solid;border-color:#f3f2f1;border-radius:0.25rem;box-sizing:border-box;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-family:"Noto Sans","Helvetica Neue","Helvetica","Arial","Liberation Sans","Roboto","Noto",sans-serif;font-size:0.75rem;font-weight:700;line-height:1.5;position:relative;padding-left:0.5rem;padding-right:0.5rem;padding-top:2px;padding-bottom:2px;background-color:#f3f2f1;color:#595959;color:#9d2b6b;background-color:#fceef4;}.css-1vjbk9u svg{display:block;height:18px;width:18px;color:#767676;}</style><div class="css-1vjbk9u e1xnxm2i0"><style data-emotion="css g6kqeb">.css-g6kqeb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:-0.5rem;margin-left:-0.5rem;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:start;-ms-flex-pack:start;-webkit-justify-content:flex-start;justify-content:flex-start;}.css-g6kqeb>.ecydgvn1{margin-top:0.5rem;margin-left:0.5rem;max-width:100%;}</style><div class="css-g6kqeb ecydgvn0"><style data-emotion="css tvvxwd">.css-tvvxwd{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;min-width:0;}</style><div class="css-tvvxwd ecydgvn1">Urgently hir ...
# <li style="margin-bottom:0px;">5+ years of estimating experience, valid CDL and bilingual in Spanish a must.</li>
# <li>Experience in writing for AAA insurance MPR program?</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active 3 days ago</span></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>, <div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@media (max-width: 400px){.css-dekpa h2{-webkit-line-clamp:4;}}</style><div class="css-dekpa e37uo190"><style data-emotion="css 1u6tfqq">.css-1u6tfqq{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;-webkit-box-orient:vertical;font-size:1.125rem;line-height:1.5rem;margin:0;color:#2d2d2d;letter-spacing:-0.06px;overflow:hidden;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;font-weight:600;-webkit-line-clamp:2;}</style><h2 class="jobTitle css-1u6tfqq eu4oa1w0" tabindex="-1"><a aria-label="full details of Substitute Teacher - Highest Pay in LA" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-ci="396849564" data-empn="7852629887101448" data-hide-spinner="true" data-hiring-event="false" data-jk="dddd7c23fbb27167" data-mobtk="1hkoetq47jgaq800" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0BI5MSIoQyz8AL-VGsOfWhkMSYPKxv_tp16wX2tGOYye2Oe14b0-y4X_S68YvLSBpCpNRyHDeN47dMwx6spyVn63jC4rWnnoScnzbr9dFZ16PlP_WlrHAQfXxiBjCzroO8ckefzJ9BQNlCB1zcOO7Cm9QS46ZcJ5qo3fZ_Gs4TrGKM6pmje1ZXEZvz3b0_mJ07SaUHRlpm7xNh6DiRZMiz392h9w0K198QAwrHBH84ehhMY3xSpPF0Tv6JZU8h5lbsNwEjMy-jfAWivMHhoYHFD2RZ_Iq1cqAUlLLG2RCtzYsMMSkzsdX02TLgirMoZajLJ5gxxgFNTR1vt9OOtvu_xIMLQr47bRGAgnmIn12luboN8WumCV3_MWl7cykHpUCXVWIeIo3un9ntJqI1yf4nSQf5lcyV5E39VkfH1iR2j8bKmpWwhBeQmKARE2a5gVlrX1z-0ldD_0oA8ErvqJcXoIi_aRunHdxTXvYf8OiC3K7Orv984hM5zy72FBb7lhiTEv54C8z6qzhf5jdznygB-fNgSS5HNvBXOS7Tj25L9bBqR3YGGnc7WVks4IdkbGB4a20n3j8h77AZ0O5kzw1IaP8uxu3jgp1KUBiLjDsOE3RDdpmy1lijd&amp;xkcb=SoC36_M3FYV4iVQ9SB0KbzkdCdPP&amp;p=1&amp;fvj=1&amp;vjs=3" id="sj_dddd7c23fbb27167" role="button"><span id="jobTitle-dddd7c23fbb27167" title="Substitute Teacher - Highest Pay in LA">Substitute Teacher - Highest Pay in LA</span></a></h2><div class="css-njufu0 e37uo190"></div></div><div class="company_location css-93zm39 e37uo190"><div class="css-1h6angx eu4oa1w0" data-testid="brandingLogo"><style data-emotion="css fyn3zj">.css-fyn3zj{height:64px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:64px;color:#767676;background-color:transparent;border:none;box-shadow:none;border-radius:0.5rem;overflow:hidden;width:100%;height:100%;margin:auto 0;}.css-fyn3zj .e1v3gfax1 svg{padding:0;width:36px;height:36px;}.css-fyn3zj >img{height:100%;}.css-fyn3zj >img{width:100%;height:auto;}</style><div class="css-fyn3zj e1v3gfax0"><img alt="Company logo" class="brandingLogo-image" src="https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/256x256/246e831ca2882fa0da81d7b64272e235"/></div></div><div data-testid="timing-attribute"><span class="css-1x7z1ps eu4oa1w0" data-testid="company-name">Teachers On Reserve</span><span aria-hidden="true" class="css-1q5aiuj eu4oa1w0"><span aria-label="4.3 out of five stars rating" class="css-1h3qsl9 eu4 ...
# <li style="margin-bottom:0px;">Connections that can lead to permanent positions.</li>
# <li>We hire caring and flexible problem solvers who make the most of each teaching day.</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active Just posted</span></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>, <div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@media (max-width: 400px){.css-dekpa h2{-webkit-line-clamp:4;}}</style><div class="css-dekpa e37uo190"><style data-emotion="css 1u6tfqq">.css-1u6tfqq{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;-webkit-box-orient:vertical;font-size:1.125rem;line-height:1.5rem;margin:0;color:#2d2d2d;letter-spacing:-0.06px;overflow:hidden;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;font-weight:600;-webkit-line-clamp:2;}</style><h2 class="jobTitle css-1u6tfqq eu4oa1w0" tabindex="-1"><a aria-label="full details of Boba Time HP/USC Team Member ($18.25/$19.5 to $30/hr with growth potential)" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="ec0fb44e11d94c6a" data-mobtk="1hkoetq47jgaq800" href="/rc/clk?jk=ec0fb44e11d94c6a&amp;bb=TbbL7lmdlxC676QxsDLCjPt11YrycW22PQfx2xtQpVHfyKA0spKncwm-SP_gMS-3sMc7k4WwBqwVkr8rj3u1xz06XXKTHqtgkN4N1Bj_WD0%3D&amp;xkcb=SoDe67M3FYV4iVQ9SB0JbzkdCdPP&amp;fccid=c5f53f74d99b6de3&amp;cmp=It%2527s-Boba-Time-USC&amp;ti=Boba+Time+Hp%2Fusc+Team+Member+%28%2418.25%2F%2419.5+to+%2430%2Fhr+With+Growth+Potential%29&amp;vjs=3" id="job_ec0fb44e11d94c6a" role="button"><span id="jobTitle-ec0fb44e11d94c6a" title="Boba Time HP/USC Team Member ($18.25/$19.5 to $30/hr with growth potential)">Boba Time HP/USC Team Member ($18.25/$19.5 to $30/hr with growth potential)</span></a></h2><div class="css-njufu0 e37uo190"></div></div><div class="company_location css-104iw4m e37uo190"><div data-testid="timing-attribute"><span class="css-1x7z1ps eu4oa1w0" data-testid="company-name">It's Boba Time HP</span><div class="css-t4u72d eu4oa1w0" data-testid="text-location">Los Angeles, CA 90007<!-- --> <div class="css-132mwr2 eu4oa1w0">(<!-- -->Exposition Park area<!-- -->)</div></div><div class="transitData"><img alt="Transit information" aria-hidden="true" class="transitTrainIcon" src="https://c03.s3.indeed.com/mosaic-provider-jobcards/dist/trainIcon.84de22fbbdfa6f5c75e8.svg"/><div class="transitName"><span><span class="transitStation">Expo / Vermont Station - Platform</span></span></div></div></div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata salary-snippet-container"><style data-emotion="css 1ihavw2">.css-1ihavw2{box-sizing:border-box;margin:0;min-width:0;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;background-color:#f3f2f1;border-radius:0.25rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0.875rem;font-weight:700;line-height:1.3125rem;color:#595959;padding:0.1875rem 0.5rem;margin-right:0.25rem;margin-bottom:0.25rem;}.css-1ihavw2 svg{width:1rem;max-height:1.25rem;}[dir="ltr"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}[dir="rtl"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}.css-1ihavw2 svg.jobCardAQSignalIcon-check{margin:0 0 0 0.25rem;}</style> ...
# <li style="margin-bottom:0px;">Must be over 18 years of age.</li>
# <li>We offer great pay, potential for promotion and pay increases, monthly bonuses and performance bonuses.</li>
# </ul></div><span class="date"><span class="visually-hidden">Posted</span>Posted 1 day ago</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">More...</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">View all <style data-emotion="css 1f8zkg3">.css-1f8zkg3{border-radius:0;color:#2557a7;font-family:"Noto Sans","Helvetica Neue","Helvetica","Arial","Liberation Sans","Roboto","Noto",sans-serif;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);border-bottom:1px solid;cursor:pointer;}.css-1f8zkg3:hover{color:#164081;}.css-1f8zkg3:active{color:#0d2d5e;}.css-1f8zkg3:focus{outline:none;border-bottom:1px solid;border-bottom-color:transparent;border-radius:4px;box-shadow:0 0 0 1px;}.css-1f8zkg3:focus:not([data-focus-visible-added]){box-shadow:none;border-bottom:1px solid;border-radius:0;}.css-1f8zkg3:visited{color:#2557a7;}.css-1f8zkg3:hover,.css-1f8zkg3:active{color:#164081;}@media (prefers-reduced-motion: reduce){.css-1f8zkg3{-webkit-transition:none;transition:none;}}.css-1f8zkg3:focus:active:not([data-focus-visible-added]){box-shadow:none;border-bottom:1px solid;border-radius:0;}</style><a class="css-1f8zkg3 e19afand0" href="/q-it%27s-boba-time-hp-l-los-angeles%2c-ca-jobs.html">It's Boba Time HP jobs in Los Angeles, CA</a></span></li><li><span class="mat">Salary Search: <a class="css-1f8zkg3 e19afand0" href="/career/team-member/salaries/90007--CA?campaignid=serp-more&amp;fromjk=ec0fb44e11d94c6a&amp;from=serp-more">Boba Time HP/USC Team Member ($18.25/$19.5 to $30/hr with growth potential) salaries in Los Angeles, CA</a></span></li><li><span class="mat">See popular <a class="css-1f8zkg3 e19afand0" href="/cmp/It's-Boba-Time-Usc/faq">questions &amp; answers about It's Boba Time HP</a></span></li></ul></div></div></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>, <div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@media (max-width:  ...
# <li>Comply with all applicable federal and state regulations regarding the operation of various types of vehicles in transporting pupils to and from school, special…</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active 5 days ago</span></div></td></tr></tbody></table><div class="location_rollup_box"><a aria-label="View similar jobs with this employer" class="css-1f8zkg3 emf9s7v0" href="/addlLoc/redirect?tk=1hkoetq47jgaq800&amp;jk=023dadec77cddcfe&amp;dest=%2Fjobs%3Fq%3D%26l%3DLos%2BAngeles%252C%2BCA%26radius%3D35%26grpKey%3DoAEB8gcFdG5mZWy4D4XH8iaqEBcKCW5vcm10aXRsZRoKYnVzIGRyaXZlcg%253D%253D" rel="nofollow"></a><div class="css-otq857 e37uo190"><a aria-label="View similar jobs with this employer" class="css-1f8zkg3 emf9s7v0" href="/addlLoc/redirect?tk=1hkoetq47jgaq800&amp;jk=023dadec77cddcfe&amp;dest=%2Fjobs%3Fq%3D%26l%3DLos%2BAngeles%252C%2BCA%26radius%3D35%26grpKey%3DoAEB8gcFdG5mZWy4D4XH8iaqEBcKCW5vcm10aXRsZRoKYnVzIGRyaXZlcg%253D%253D" rel="nofollow"></a><div class="css-2c8j1f eu4oa1w0"><a aria-label="View similar jobs with this employer" class="css-1f8zkg3 emf9s7v0" href="/addlLoc
=1&amp;vjs=3" id="sj_df4507564879c6bb" role="button"><span id="jobTitle-df4507564879c6bb" title="Full Charge Bookkeeper (Music Touring)">Full Charge Bookkeeper (Music Touring)</span></a></h2><div class="css-njufu0 e37uo190"></div></div><div class="company_location css-104iw4m e37uo190"><div data-testid="timing-attribute"><span class="css-1x7z1ps eu4oa1w0" data-testid="company-name">Woodwest Business Management</span><div class="css-t4u72d eu4oa1w0" data-testid="text-location">El Segundo, CA 90245</div></div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata salary-snippet-container"><style data-emotion="css 1ihavw2">.css-1ihavw2{box-sizing:border-box;margin:0;min-width:0;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;background-color:#f3f2f1;border-radius:0.25rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0.875rem;font-weight:700;line-height:1.3125rem;color:#595959;padding:0.1875rem 0.5rem;margin-right:0.25rem;margin-bottom:0.25rem;}.css-1ihavw2 svg{width:1rem;max-height:1.25rem;}[dir="ltr"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}[dir="rtl"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}.css-1ihavw2 svg.jobCardAQSignalIcon-check{margin:0 0 0 0.25rem;}</style><div class="css-1ihavw2 eu4oa1w0"  ...
# <li>We are currently looking for an Account Manager/Bookkeeper to assist with our clients in the entertainment/sports industry (music/new media).</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active 3 days ago</span></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>, <div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@media (max-width: 400px){.css-dekpa h2{-webkit-line-clamp:4;}}</style><div class="css-dekpa e37uo190"><style data-emotion="css 1u6tfqq">.css-1u6tfqq{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;-webkit-box-orient:vertical;font-size:1.125rem;line-height:1.5rem;margin:0;color:#2d2d2d;letter-spacing:-0.06px;overflow:hidden;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;font-weight:600;-webkit-line-clamp:2;}</style><h2 class="jobTitle css-1u6tfqq eu4oa1w0" tabindex="-1"><a aria-label="full details of 988 Crisis Counselor" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="eaf70352b696ce2a" data-mobtk="1hkoetq47jgaq800" href="/rc/clk?jk=eaf70352b696ce2a&amp;bb=TbbL7lmdlxC676QxsDLCjNGDdH2POR6uWTW08_x8kfResZ7yXz4TFd0Shcr667J01NYCBkwIMP9cdkun1LwhNl5eDzXa4YU-XAFeyR0ZE3k%3D&amp;xkcb=SoCQ67M3FYV4iVQ9SB0DbzkdCdPP&amp;fccid=3feef3ed004cb14d&amp;vjs=3" id="job_eaf70352b696ce2a" role="button"><span id="jobTitle-eaf70352b696ce2a" title="988 Crisis Counselor">988 Crisis Counselor</span></a></h2><div class="css-njufu0 e37uo190"></div></div><div class="company_location css-104iw4m e37uo190"><div data-testid="timing-attribute"><span class="css-1x7z1ps eu4oa1w0" data-testid="company-name">Didi Hirsch Mental Health Services</span><div class="css-t4u72d eu4oa1w0" data-testid="text-location">Los Angeles, CA 90067</div></div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata salary-snippet-container"><style data-emotion="css 1ihavw2">.css-1ihavw2{box-sizing:border-box;margin:0;min-width:0;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;background-color:#f3f2f1;border-radius:0.25rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0.875rem;font-weight:700;line-height:1.3125rem;color:#595959;padding:0.1875rem 0.5rem;margin-right:0.25rem;margin-bottom:0.25rem;}.css-1ihavw2 svg{width:1rem;max-height:1.25rem;}[dir="ltr"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}[dir="rtl"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}.css-1ihavw2 svg.jobCardAQSignalIcon-check{margin:0 0 0 0.25rem;}</style><div class="css-1ihavw2 eu4oa1w0" data-testid="attribute_snippet_testid">$24 an hour</div></div><div class="metadata"><div class="css-1ihavw2 eu4oa1w0" data-testid="attribute_snippet_testid">Full-time</div></div><div class="css-1ihavw2 eu4oa1w0">Minimum of 20 hours per week</div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="css-1u8dvic eu4oa1w0" role="presentation"><tbody><style data-emotion="css mvf9iq">.css-mvf9iq{box-sizing:border-box;margin:0;min-width:0;display:block;padding-right:0;padding-left:1rem;padding-bottom:0.25rem;}[dir="rtl"] .css-mvf9iq{padding-right:1rem;padding-left:0;}</style><tr class="css-mvf9iq eu4oa ...
# <li>Current valid driver’s license issued by the state of current residence and a driving record acceptable to the Agency’s insurance carrier.</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active 4 days ago</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">More...</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">View all <style data-emotion="css 1f8zkg3">.css-1f8zkg3{border-radius:0;color:#2557a7;font-family:"Noto Sans","Helvetica Neue","Helvetica","Arial","Liberation Sans","Roboto","Noto",sans-serif;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);border-bottom:1px solid;cursor:pointer;}.css-1f8zkg3:hover{color:#164081;}.css-1f8zkg3:active{color:#0d2d5e;}.css-1f8zkg3:focus{outline:none;border-bottom:1px solid;border-bottom-color:transparent;border-radius:4px;box-shadow:0 0 0 1px;}.css-1f8zkg3:focus:not([data-focus-visible-added]){box-shadow:none;border-bottom:1px solid;border-radius:0;}.css-1f8zkg3:visited{color:#2557a7;}.css-1f8zkg3:hover,.css-1f8zkg3:active{color:#164081;}@media (prefers-reduced-motion: reduce){.css-1f8zkg3{-webkit-transition:none;transition:none;}}.css-1f8zkg3:focus:active:not([data-focus-visible-added]){box-shadow:none;border-bottom:1px solid;border-radius:0;}</style><a class="css-1f8zkg3 e19afand0" href="/q-didi-hirsch-mental-health-services-l-los-angeles,-ca-jobs.html">Didi Hirsch Mental Health Services jobs in Los Angeles, CA</a></span></li><li><span class="mat">Salary Search: <a class="css-1f8zkg3 e19afand0" href="/career/crisis-counselor/salaries/90067--CA?campaignid=serp-more&amp;fromjk=eaf70352b696ce2a&amp;from=serp-more">988 Crisis Counselor salaries in Los Angeles, CA</a></span></li><li><span class="mat">See popular <a class="css-1f8zkg3 e19afand0" href="/cmp/Didi-Hirsch-Mental-Health-Services/faq">questions &amp; answers about Didi Hirsch Mental Health Services</a></span></li></ul></div></div></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>, <div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@me ...
# <li style="margin-bottom:0px;">You can work on your own schedule.</li>
# <li style="margin-bottom:0px;">A bachelor's degree (completed or in progress).</li>
# <li>You will have conversations with chatbots in order to measure their progress,…</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active 12 days ago</span></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>, <div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@media (max-width: 400px){.css-dekpa h2{-webkit-line-clamp:4;}}</style><div class="css-dekpa e37uo190"><style data-emotion="css 1u6tfqq">.css-1u6tfqq{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;-webkit-box-orient:vertical;font-size:1.125rem;line-height:1.5rem;margin:0;color:#2d2d2d;letter-spacing:-0.06px;overflow:hidden;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;font-weight:600;-webkit-line-clamp:2;}</style><h2 class="jobTitle css-1u6tfqq eu4oa1w0" tabindex="-1"><a aria-label="full details of Appointment Clerk" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="2c93ecb7f3b55ddd" data-mobtk="1hkoetq47jgaq800" href="/rc/clk?jk=2c93ecb7f3b55ddd&amp;bb=TbbL7lmdlxC676QxsDLCjBOixfORsKJ4AS5gALwahcpxHN7_hsaTosESuLFhPJ_dDhkk0wmOlSqTNB9EjdjR91GcAcAV1pHikrVipvxbdtk%3D&amp;xkcb=SoC567M3FYV4iVQ9SB0BbzkdCdPP&amp;fccid=48ecd526e3aa3225&amp;vjs=3" id="job_2c93ecb7f3b55ddd" role="button"><span id="jobTitle-2c93ecb7f3b55ddd" title="Appointment Clerk">Appointment Clerk</span></a></h2><div class="css-njufu0 e37uo190"></div></div><div class="company_location css-104iw4m e37uo190"><div data-testid="timing-attribute"><span class="css-1x7z1ps eu4oa1w0" data-testid="company-name">Kaiser Permanente</span><div class="css-t4u72d eu4oa1w0" data-testid="text-location">Anaheim, CA</div></div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata salary-snippet-container"><style data-emotion="css 1ihavw2">.css-1ihavw2{box-sizing:border-box;margin:0;min-width:0;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;background-color:#f3f2f1;border-radius:0.25rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0.875rem;font-weight:700;line-height:1.3125rem;color:#595959;padding:0.1875rem 0.5rem;margin-right:0.25rem;margin-bottom:0.25rem;}.css-1ihavw2 svg{width:1rem;max-height:1.25rem;}[dir="ltr"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}[dir="rtl"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}.css-1ihavw2 svg.jobCardAQSignalIcon-check{margin:0 0 0 0.25rem;}</style><div class="css-1ihavw2 eu4oa1w0" data-testid="attribute_snippet_testid">$25.30 - $28.03 an hour</div></div><div class="metadata"><div class="css-1ihavw2 eu4oa1w0" data-testid="attribute_snippet_testid">Full-time</div></div><div class="metadata"><div class="css-1ihavw2 eu4oa1w0" data-testid="attribute_snippet_testid">Day shift</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="css-1u8dvic eu4oa1w0" role="presentation"><tbody><style data-emotion="css mvf9iq">.css-mvf9iq{box-sizing:border-box;margin:0;min-width:0;display:block;padding-right:0;padding-left:1rem;padding-bottom:0.25rem;}[dir="rtl"] .css-mvf9iq{padding-right:1rem;padding-left:0;}</style><t ...
# <li style="margin-bottom:0px;">Initiate telephone calls to physicians or other medical office staff when indicated to assist members.</li>
# <li>Operates in a high volume, highly structured call center…</li>
# </ul></div><span class="date"><span class="visually-hidden">Posted</span>Posted 1 day ago</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">More...</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">View all <style data-emotion="css 1f8zkg3">.css-1f8zkg3{border-radius:0;color:#2557a7;font-family:"Noto Sans","Helvetica Neue","Helvetica","Arial","Liberation Sans","Roboto","Noto",sans-serif;-webkit-text-decoration:none;text-decoration:none;-webkit-transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);border-bottom:1px solid;cursor:pointer;}.css-1f8zkg3:hover{color:#164081;}.css-1f8zkg3:active{color:#0d2d5e;}.css-1f8zkg3:focus{outline:none;border-bottom:1px solid;border-bottom-color:transparent;border-radius:4px;box-shadow:0 0 0 1px;}.css-1f8zkg3:focus:not([data-focus-visible-added]){box-shadow:none;border-bottom:1px solid;border-radius:0;}.css-1f8zkg3:visited{color:#2557a7;}.css-1f8zkg3:hover,.css-1f8zkg3:active{color:#164081;}@media (prefers-reduced-motion: reduce){.css-1f8zkg3{-webkit-transition:none;transition:none;}}.css-1f8zkg3:focus:active:not([data-focus-visible-added]){box-shadow:none;border-bottom:1px solid;border-radius:0;}</style><a class="css-1f8zkg3 e19afand0" href="/q-kaiser-permanente-l-anaheim,-ca-jobs.html">Kaiser Permanente jobs in Anaheim, CA</a> - <a class="css-1f8zkg3 e19afand0" href="/l-anaheim,-ca-jobs.html">Anaheim jobs</a> - <a class="css-1f8zkg3 e19afand0" href="/q-clerk-l-anaheim,-ca-jobs.html">Clerk jobs in Anaheim, CA</a></span></li><li><span class="mat">Salary Search: <a class="css-1f8zkg3 e19afand0" href="/career/clerk/salaries/Anaheim--CA?campaignid=serp-more&amp;fromjk=2c93ecb7f3b55ddd&amp;from=serp-more">Appointment Clerk salaries in Anaheim, CA</a></span></li><li><span class="mat">See popular <a class="css-1f8zkg3 e19afand0" href="/cmp/Kaiser-Permanente/faq">questions &amp; answers about Kaiser Permanente</a></span></li></ul></div></div></div></td></tr></tbody></table><div class="location_rollup_box"><a aria-label="View similar jobs with this employer" class="css-1f8zkg3 emf9s7v0" href="/addlLoc/redirect?tk=1hkoetq47jgaq800&amp;jk=2c93ecb7f3b55ddd&amp;dest=%2Fjobs%3Fq%3D%26l%3DLos%2BAngeles%252C%2BCA%26radius%3D35%26grpKey%3DoAEBmAOZqwigAwHyBwV0bmZlbLgP9kw%253D" rel="nofollow"></a><div class="css-otq857 e37uo190"><a aria-label="View similar jobs with this employer" class="css-1f8zkg3 emf9s7v0" href="/addlLoc/redirect?tk=1hkoetq47jgaq800&amp;jk=2c93ecb7f3b55ddd&amp;dest=%2Fjobs%3Fq%3D%26l%3DLos%2BAngeles%252C%2BCA%26radius%3D35%26grpKey%3DoAEBmAOZqwigAwHyBwV0bmZlbLgP9kw%253D" rel="nofollow"></a><div class="css-2c8j1f eu4oa1w0"><a aria-label="View similar jobs with this employer" class="css-1f8zkg3 emf9s7v0" href="/addlLoc/redirect?tk=1hkoetq47jgaq800&amp;jk=2c93e ...
# <li style="margin-bottom:0px;">Communicate, negotiate and define Import processing needs with Vendors.</li>
# <li>Qualifications:* Must have strong ability to prioritize, organize and direct production…</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active 2 days ago</span></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>, <div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@media (max-width: 400px){.css-dekpa h2{-webkit-line-clamp:4;}}</style><div class="css-dekpa e37uo190"><style data-emotion="css 1u6tfqq">.css-1u6tfqq{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;-webkit-box-orient:vertical;font-size:1.125rem;line-height:1.5rem;margin:0;color:#2d2d2d;letter-spacing:-0.06px;overflow:hidden;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;font-weight:600;-webkit-line-clamp:2;}</style><h2 class="jobTitle css-1u6tfqq eu4oa1w0" tabindex="-1"><a aria-label="full details of Payroll Clerk" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-ci="424093020" data-empn="2196412318964146" data-hide-spinner="true" data-hiring-event="false" data-jk="06abeaf8952a6b33" data-mobtk="1hkoetq47jgaq800" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0BFeqtvNl4OrNo7a4ZkDjtps68NwvkChYKl1At9v1P-jI0ZSzLJUPGCV4LHlgon4KCbLW2E8mZp2IqnutssCW3wVQVmTNPwvIJoIULhCMlR85j3_cbbWzLA51LvfUe45VvxiYzshU3pr9T3xhjkfugHQsw-31PCCcovRKHWfd2hpAOh7EBU6h0yLlULWnpPq0tjYWRd5qX8MWkRhM402UKGD-pMS2YRCk9JxETwtMIOBJTGcgRGnkPBXAGWoLj4dHs2oZta1NaGhPidyvJ22EOgleGDNdBMDV6K-DMztmkJ--Pj_n58a7RrQrWh1H-40bEeWHR6EGAR0MzsydyzeF0IeKcZNPb3fWoumImTQx0HZX6lvU8jllpQYn-soxu8ek1vroIEEwt-T-hJYRA9SivyHCMEK4dSK0alyKxqupC817rW58X3b_Iqrqn70LS26o4eeqywe-YOz5zUDOjkSy6YniP-gGhR5rCavosxvkmHSzLWJRr9h5-HEjbd1viuC0YqAOylLzaMYHs5zL6mb30923fkChxpwzUgQLzfVx93dWxNnfFp9xh7GK_oheiBOV7peYoxpxXwWAFm7hsIxxoXPJmPbZvcrWZux1oQjqc1pg==&amp;xkcb=SoB36_M3FYV4iVQ9SB0HbzkdCdPP&amp;p=12&amp;fvj=1&amp;vjs=3" id="sj_06abeaf8952a6b33" role="button"><span id="jobTitle-06abeaf8952a6b33" title="Payroll Clerk">Payroll Clerk</span></a></h2><div class="css-njufu0 e37uo190"></div></div><div class="company_location css-104iw4m e37uo190"><div data-testid="timing-attribute"><span class="css-1x7z1ps eu4oa1w0" data-testid="company-name">Brody Pennell</span><div class="css-t4u72d eu4oa1w0" data-testid="text-location">Los Angeles, CA 90034<!-- --> <div class="css-132mwr2 eu4oa1w0">(<!-- -->Mid City area<!-- -->)</div></div></div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata salary-snippet-container"><style data-emotion="css 1ihavw2">.css-1ihavw2{box-sizing:border-box;margin:0;min-width:0;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;background-color:#f3f2f1;border-radius:0.25rem;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:0.875rem;font-weight:700;line-height:1.3125rem;color:#595959;padding:0.1875rem 0.5rem;margin-right:0.25rem;margin-bottom:0.25rem;}.css-1ihavw2 svg{width:1rem;max-height:1.25rem;}[dir="ltr"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}[dir="rtl"] .css-1ihavw2 svg:first-child{margin:0 0 0 0.25rem;}.css-1ihavw2 svg.jobCardAQSignalIcon-check{margin:0 0 0 0.25rem;}</style><div class="css-1ihavw2 eu4oa1w0" data-testid="attribute_snippet_testid">$20 - $24 an hour</di ...
# <li style="margin-bottom:0px;">High school diploma or equivalent; additional education in accounting, finance, or a related field is a plus.</li>
# <li>As a Payroll Clerk at Brody Pennell, you will play…</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active Just posted</span></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>, <div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@media (max-width: 400px){.css-dekpa h2{-webkit-line-clamp:4;}}</style><div class="css-dekpa e37uo190"><style data-emotion="css 1u6tfqq">.css-1u6tfqq{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;-webkit-box-orient:vertical;font-size:1.125rem;line-height:1.5rem;margin:0;color:#2d2d2d;letter-spacing:-0.06px;overflow:hidden;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;font-weight:600;-webkit-line-clamp:2;}</style><h2 class="jobTitle css-1u6tfqq eu4oa1w0" tabindex="-1"><a aria-label="full details of Litigation Secretary" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-ci="377339462" data-empn="6036772844305182" data-hide-spinner="true" data-hiring-event="false" data-jk="7e5d41b827a5188b" data-mobtk="1hkoetq47jgaq800" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0CCaj8DrauNq8rt6ac_VOaL6PQNf_k7o0cHhyWN4EjDKONRijg5Dgjk1WcuIt0o6Qg0TRIpjdhNs4ZxWTs57vh6NsHPt_AzXjEINjFjN_7YZA8N2heM8yLCe-H3PSkZvmvED2Es471YszUPh9lSJUDixQGvASLGnCgo5DyVa_Ct91rCgsxTb-8FnKWJ9yeWenHVtwPts4dKHNyuzGGm1BgPr89wpEP6Rn2J275UHCuRWZswyWJGIwFiQE5-b-wFonCkmWhj7siLlj8pfsEpufEVx8_9rp0SO013rClaQQgPoTI9MrLgzrB1Hrih3YzY_0njnjTeG2p90YdTQbxwYR2Qwlc9mXC89kvVrQJ0RdAY1y3S3188geh0mLHXdIQtwWx2JOariPwyJ2Swe4RpgcxjP2RMxc2SJ7vM_6ldZLsfJxkSeunUBnZNjbqLXtY0oDBBBFPeO_D_Fh7NzVIqaY3X2fJoeazoyjpVCg4brJi8msesU63vUIRI4WEFsDF3AJ_VH1v4BDTzNDjXaIKb7clm7u2KhVpbS-UVQKHduT64hV1ImKtHwL3yq_kMkAW76VRGsEmL2iN_tuQlhRfmiVSUIyGUeTBaj0TMoBluPlJRYEiXnC--gd4J&amp;xkcb=SoDD6_M3FYV4iVQ9SB0GbzkdCdPP&amp;p=13&amp;fvj=1&amp;vjs=3" id="sj_7e5d41b827a5188b" role="button"><span id="jobTitle-7e5d41b827a5188b" title="Litigation Secretary">Litigation Secretary</span></a></h2><div class="css-njufu0 e37uo190"><div class="css-kyg8or eu4oa1w0"><style data-emotion="css 1vjbk9u">.css-1vjbk9u{-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:1px solid;border-color:#f3f2f1;border-radius:0.25rem;box-sizing:border-box;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-family:"Noto Sans","Helvetica Neue","Helvetica","Arial","Liberation Sans","Roboto","Noto",sans-serif;font-size:0.75rem;font-weight:700;line-height:1.5;position:relative;padding-left:0.5rem;padding-right:0.5rem;padding-top:2px;padding-bottom:2px;background-color:#f3f2f1;color:#595959;color:#9d2b6b;background-color:#fceef4;}.css-1vjbk9u svg{display:block;height:18px;width:18px;color:#767676;}</style><div class="css-1vjbk9u e1xnxm2i0"><style data-emotion="css g6kqeb">.css-g6kqeb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-top:-0.5rem;margin-left:-0.5rem;-webkit-box-flex-wrap:wrap;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:start;-ms-flex-pack:start;-webkit-justify- ...
# <li>The litigation secretary will assist attorney(s) by providing clerical and research support services including, but not limited to, document preparation and…</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active 3 days ago</span></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>, <div class="slider_container css-12igfu2 eu4oa1w0" data-testid="slider_container" dir="auto"><div class="slider_list css-ltdjbe eu4oa1w0"><div class="slider_item css-mk9n32 eu4oa1w0" data-testid="slider_item"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="big6_visualChanges css-1v79ar eu4oa1w0" role="presentation"><tbody><tr><td class="resultContent css-1qwrrf0 eu4oa1w0"><style data-emotion="css dekpa">.css-dekpa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;box-sizing:border-box;margin:0;min-width:0;overflow:hidden;text-overflow:ellipsis;-webkit-flex-direction:column-reverse;-ms-flex-direction:column-reverse;flex-direction:column-reverse;-webkit-padding-end:2.6rem;padding-inline-end:2.6rem;}@media (max-width: 400px){.css-dekpa h2{-webkit-line-clamp:4;}}</style><div class="css-dekpa e37uo190"><style data-emotion="css 1u6tfqq">.css-1u6tfqq{box-sizing:border-box;margin:0;min-width:0;display:-webkit-box;-webkit-box-orient:vertical;font-size:1.125rem;line-height:1.5rem;margin:0;color:#2d2d2d;letter-spacing:-0.06px;overflow:hidden;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;font-weight:600;-webkit-line-clamp:2;}</style><h2 class="jobTitle css-1u6tfqq eu4oa1w0" tabindex="-1"><a aria-label="full details of Urban Forestry Lead" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-ci="422255983" data-empn="5718563846207654" data-hide-spinner="true" data-hiring-event="false" data-jk="7c136eaf19a68192" data-mobtk="1hkoetq47jgaq800" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0CzayKEpdZr6H7UsiYVacYk77FMUYLUmm2idJzRRGBeEHLGn33ZE_cQ_SqUz4tdpoADTk8Fzg1Q1VSJzbNgxHmh57nbHVVBVcISRcGNCpILT9TDSfTto_S77dAKhEO8ZZ8oi1KeGtqPcIZqhVT8dDGoEDCAnQr7GZa6Q6tgTcB0MXpd7PEa5LlI-NDhZcMfOfjwG7oz8G0pQ8cF1YZhGZJ9I6lYvGWb4svZVwRgu93gkadCFWmYV2MQdY2KiIG-f9M9RrrKdE6cc-7KFL_Bqo2E7TNoVceNyNnEJS5EY6MPnQDb4pqP1_4utOcYVVwN-OoXpCjGVHOVplW5znzqaz5CF39q6MQ35H8V2MElDKk6cA_kSuFL49GKuiJxsTAVPaWbzlprQUeH1XbmWGLDmN84ex5dapOyF328X9wCdGSu4kPNcujwc-Pa3H8O8m3G_pHlxVEX-vW9mg46DKFQgAtqZFSqf4zXRVulILxE5pv1ZGcfUwpiVwod9Q7LBu_vMdCdSGjG0rWMZpqTXDpVPG1Uvi4smFhgSroFGUizNZ1S6dRR_uhFgxcJ9Qv1WKgpD4JfrmJRvTg1bB44BCmF9zezmTTRrxLbGj2N0CL5sCBYqA==&amp;xkcb=SoBe6_M3FYV4iVQ9SB0FbzkdCdPP&amp;p=14&amp;fvj=1&amp;vjs=3" id="sj_7c136eaf19a68192" role="button"><span id="jobTitle-7c136eaf19a68192" title="Urban Forestry Lead">Urban Forestry Lead</span></a></h2><div class="css-njufu0 e37uo190"></div></div><div class="company_location css-104iw4m e37uo190"><div data-testid="timing-attribute"><span class="css-1x7z1ps eu4oa1w0" data-testid="company-name">Koreatown Youth &amp; Community Center</span><span aria-hidden="true" class="css-1q5aiuj eu4oa1w0"><span aria-label="4.1 out of five stars rating" class="css-1h3qsl9 eu4oa1w0" data-testid="holistic-rating" role="img"><span aria-hidden="true">4.1</span><span class="css-1nc1e2q eu4oa1w0"><svg aria-hidden="true" fill="none" height="12" role="presentation" viewbox="0 0 16 16" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149443 6.61581L4.0852 10.0254L2.90318 15.0922C2.81653 15.4636 3.21932 15.7563 3.54584 15.5593L8 12.8709Z" fill="#767676"></path></svg></span></span></span><div class="css-t4u72d eu4oa1w0" data-testid="text-location">Los Angeles, CA 90015<!-- --> <div class="css-132mwr2 eu4oa1w0">(<!-- -->Pico Union area<!-- -->)</div></div></div></div><div class="heading6 tapItem-gutter metadataCo ...
# <li>A valid Class C California Driver License, access to personal automobile, driving record clearance and proof of auto insurance..</li>
# </ul></div><span class="date"><span class="visually-hidden">Employer</span>Active Just posted</span></div></td></tr></tbody></table><div class="ctaContainer"></div><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div>]
